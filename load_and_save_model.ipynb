# %%
import pickle 
from diffusers import DiffusionPipeline
pipeline = DiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5")
# Out:
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# /Users/ryanmitchell/.pyenv/versions/3.10.6/lib/python3.10/site-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(

# %%
prompt = "a photo of an astronaut riding a horse on mars"
image = pipeline(prompt).images[0]
image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
# Save model as .pkl
with open("pipeline.pkl", "wb") as f:
    pickle.dump(pipeline, f)
